# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import nltk
from nltk.corpus import cmudict
nltk.download('cmudict')
import pickle
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     /Users/kushaltirumala/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!

# %%
with open("../data/shakespeare.txt", "r") as f:
    data = f.read()

# %%
def get_sonnets(filename):
    """ Returns list of separate sonnets in the file. 
    Each line of a sonnet is a list of words (tokens). """
    with open(filename) as file:
        sons, son = [], []
        for line in file:
            line = line.strip()
            if line.isdigit() == False:
                lst = line.lower().translate(str.maketrans('', '', ':;,.?!()')).split()
                if len(lst) > 0: # count words in line
                    son.append(lst)
                elif len(son) > 0:
                    sons.append(son)
                    son = []
    sons.append(son) # add the final sonnet
    return sons
file = '../data/shakespeare.txt'
sonnets = get_sonnets(file)

# The sonnets 99 and 126 (at indices 98 and 125)
# do not count as sonnets, since they are not 14 lines long
for i in range(len(sonnets)):
    if len(sonnets[i]) != 14:
        print(i)
        
sonnets = sonnets[:98] + sonnets[99:125] + sonnets[126:]

d = cmudict.dict()
def count_syl(word):
    """ Returns number of syllables in a word. Taken
    from StackOverflow. """
    if word in d:
        return len(list(y for y in d[word][0] if y[-1].isdigit()))
    count = 0
    vowels = 'aeiouy'
    
    if word[0] in vowels:
        count +=1
    for index in range(1,len(word)):
        if word[index] in vowels and word[index-1] not in vowels:
            count +=1
    if word.endswith('e'):
        count -= 1
    if word.endswith('le'):
        count+=1
    if count == 0:
        count +=1
    return count

def get_syl(dic_to_ids):
    """ Returns dictionary of IDs to syllables given 
    a dictionary mapping words to ids. """
    dic = {}
    for word in dic_to_ids.keys():
        id_ = dic_to_ids[word]
        if "'" in word:
            dic[id_] = 1
        else:
            dic[id_] = sum(count_syl(w) for w in word.split("-"))
        
    return dic

def get_id(lines):
    """ Returns dictionary of words to IDs and 
    dictionary of IDs to words. """
    dic_to_ids, dic_to_words = {}, {}
    id_ = 0
    for line in lines:
        for word in line:
            if word not in dic_to_ids:
                dic_to_ids[word] = id_
                dic_to_words[id_] = word
                id_ += 1
    return dic_to_ids, dic_to_words

def get_mappings(sonnets, name):
    """ Returns dictionary of words to IDs, dictionary of IDs to words, 
    and dictionary of IDs to syllables. """    
    lines = list(itertools.chain.from_iterable(sonnets)) # list of lines
    dic_to_ids, dic_to_words = get_id(lines)
    dic_syl = get_syl(dic_to_ids)
    
    with open(name, 'wb') as f:
        pickle.dump((dic_to_ids, dic_to_words, dic_syl), f)
    
    return dic_to_ids, dic_to_words, dic_syl

dic_to_ids, dic_to_words, dic_syl = get_mappings(sonnets, 'shakespeare_dics.pkl')
# Out:
# 98
# 125

# %%
ids_to_dic = {v: k for k,v in dic_to_ids.items()}

# %%
import copy

hehe = copy.deepcopy(sonnets)
for i in range(len(sonnets)):
    for j in range(len(sonnets[i])):
        for k in range(len(sonnets[i][j])):
            hehe[i][j][k] = dic_to_ids[sonnets[i][j][k]]
hehe = np.array(hehe)

# %%
fin = []
for i in range(len(hehe)):
    temp = []
    for j in range(len(hehe[i])):
        for k in range(len(hehe[i][j])):
            temp.append(hehe[i][j][k])
    fin.append(temp)
fin = np.array(fin)

# %%
from HMM_sol import *
# want to seed words, and generate the sonnet in reverse based on that seeded word
# so first we generate the training data for the end of line stuff that (hopefully rhymes)
def words_to_ids(data):
    ans = copy.deepcopy(data)
    for i in range(len(data)):
        for j in range(len(data[i])):
            ans[i][j] = dic_to_ids[data[i][j]]
    return ans

# %%
r = []
for i in range(len(hehe)):
    temp = []
    for j in range(len(hehe[i])):
        temp.append(hehe[i][j][len(hehe[i][j]) - 1])
    r.append(temp)
HMM_rhyming = unsupervised_HMM(r, 30, 200, D_len=len(ids_to_dic))
# Out:
# 3202
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
# Iteration: 110
# Iteration: 120
# Iteration: 130
# Iteration: 140
# Iteration: 150
# Iteration: 160
# Iteration: 170
# Iteration: 180
# Iteration: 190
# Iteration: 200

# %%
emission, states = HMM_rhyming.generate_emission(14)

# %%
x = ' '.join([str(ids_to_dic[i]) for i in emission])

# %%
x
# Out:
# 'state acquainted done depart pride lies friend amazeth ordering thence dignity offence dead flatter'

# %%
import pickle
with open('../shakespeare_rhymes.pkl', 'rb') as f:
    rhyme_data_raw = pickle.load(f)

# %%
rhyme_data_raw
# Out:
# [['cease', 'increase', 'lease', 'decease', 'decrease', 'excess'],
#  ['i',
#   'fee',
#   'die',
#   'memory',
#   'eye',
#   'legacy',
#   'deny',
#   'qualify',
#   'thee',
#   'fly',
#   'by',
#   'majesty',
#   'usury',
#   'husbandry',
#   'dignity',
#   'sky',
#   'eternity',
#   'me',
#   'canopy',
#   'be',
#   'ye',
#   'see',
#   'gravity',
#   'thereby',
#   'lie',
#   'flattery',
#   'defy',
#   'melancholy',
#   'alchemy',
#   'history',
#   'enmity',
#   'constancy',
#   'why',
#   'posterity',
#   'decree',
#   'free',
#   'fortify',
#   'remedy',
#   'idolatry',
#   'masonry'],
#  ['devise',
#   'prophecies',
#   'cries',
#   'spies',
#   'despise',
#   'eyes',
#   'subtleties',
#   'lies',
#   'arise'],
#  ['cruel', 'fuel', 'jewel'],
#  ['content',
#   'excellent',
#   'spent',
#   'invent',
#   'argument',
#   'rent',
#   'ornament',
#   'monument'],
#  ['bring',
#   'ordering',
#   'thing',
#   'niggarding',
#   'spring',
#   'prefiguring',
#   'wing',
#   'king',
#   'sing'],
#  ['allow', 'bow', 'mow', 'brow', 'now', 'bough', 'how'],
#  ['stelled', 'held', 'field'],
#  ['days', 'decays', 'praise', 'lays'],
#  ['muse', "excuse'", 'use', 'abuse'],
#  ['define', 'line', 'shine', 'thine', 'divine', 'mine'],
#  ['hold', 'bold', 'told', 'old', 'behold', 'uphold', 'cold', 'untold'],
#  ['renewest', 'viewest'],
#  ['mother', 'another'],
#  ['dumb', 'womb', 'room', 'sum', 'tomb', 'come', 'doom'],
#  ['time', 'rhyme', 'prime', 'crime'],
#  ['contend',
#   'end',
#   'friend',
#   'mend',
#   'fiend',
#   'spend',
#   "friend'",
#   'depend',
#   'commend',
#   'tend',
#   'lend'],
#  ['live', 'give', 'achieve'],
#  ['stone',
#   'gone',
#   'alone',
#   'groan',
#   'moan',
#   'loan',
#   'one',
#   'prone',
#   'foregone',
#   'none',
#   'anon',
#   'upon',
#   'on',
#   "none'"],
#  ['leave', 'deceive'],
#  ['same', 'frame', 'fame', 'blame', 'name', 'shame'],
#  ['bell', 'tell', 'hell', 'smell', 'well', 'sell', 'excel', 'dwell'],
#  ['year',
#   'ear',
#   'bear',
#   'there',
#   'everywhere',
#   'elsewhere',
#   'tear',
#   'fear',
#   'forbear',
#   'dear',
#   'cheer',
#   'swear',
#   'clear',
#   'were',
#   'where',
#   'near',
#   'appear',
#   'wear'],
#  ['bereft', 'left'],
#  ['pass', 'glass', 'was'],
#  ['sweet', 'meet', 'greet'],
#  ['chase', 'case', 'face', 'disgrace', 'deface', 'grace', 'place'],
#  ['distilled', 'self-killed'],
#  ['depart', 'convert', 'heart', 'art', 'desert', 'part', 'impart'],
#  ['repair', 'fair', 'despair', 'air', 'heir'],
#  ['write',
#   'light',
#   'sight',
#   'rite',
#   'delight',
#   'aright',
#   'bright',
#   'quite',
#   'fight',
#   'right',
#   'night',
#   'spite',
#   'white',
#   'plight',
#   'recite',
#   'appetite',
#   'might'],
#  ['skill',
#   'fill',
#   "'will'",
#   'quill',
#   'kill',
#   'will',
#   'ill',
#   'still',
#   'fulfil',
#   'hill'],
#  ['rage', 'page', 'pilgrimage', 'equipage', 'stage', 'age', 'presage'],
#  ['rare', 'prepare', 'care', 'car', 'are', 'compare'],
#  ['repay',
#   'gay',
#   're-survey',
#   'clay',
#   'stay',
#   'decay',
#   'survey',
#   'key',
#   'they',
#   'away',
#   'sway',
#   'pay',
#   'say',
#   'betray',
#   'way',
#   'play',
#   'may',
#   'day',
#   'lay',
#   'array'],
#  ['son', 'noon', 'won'],
#  ['sadly', 'gladly'],
#  ['joy', 'annoy'],
#  ['confounds', 'sounds'],
#  ['wife', 'strife', 'knife', 'life'],
#  ['weep', 'keep', 'steep', 'asleep'],
#  ['confined',
#   'find',
#   'grind',
#   'mind',
#   'blind',
#   'bind',
#   'wind',
#   'kind',
#   'behind'],
#  ['wit', 'knit', 'it', 'sit', 'writ'],
#  ['befits', 'sits', 'commits'],
#  ['many', 'any'],
#  ['evident', 'unprovident'],
#  ['hate',
#   'ruminate',
#   "hate'",
#   'ruinate',
#   'anticipate',
#   'accumulate',
#   'gait',
#   'translate',
#   'fate',
#   'debate',
#   'gate',
#   'state',
#   'advocate'],
#  ['desire', 'require', 'fire', 'expire', 'conspire', 'admire'],
#  ['remove', 'above', 'approve', 'love', "love'", 'move', 'prove'],
#  ["ow'st", "bestow'st", "grow'st"],
#  ['convertest', 'departest'],
#  ['more', 'yore', 'score', 'shore', 'before', "o'er", 'abhor', 'store'],
#  ['cherish', 'perish'],
#  ['leaves', 'sheaves'],
#  ['beard', 'herd'],
#  ['forsake', 'take', 'awake', 'sake', 'partake', 'make'],
#  ['know',
#   'overthrow',
#   'owe',
#   'wilful-slow',
#   'so',
#   'slow',
#   'show',
#   'grow',
#   'woe',
#   'no',
#   'flow',
#   'go'],
#  ['offence', 'thence', 'intelligence', 'defence', 'hence'],
#  ['pluck', 'luck'],
#  ['quality', 'astronomy'],
#  ['derive', 'thrive'],
#  ['prognosticate', 'expiate', 'temperate', 'invocate', 'date'],
#  ['rose', 'grows', 'suppose', 'those', 'foes', 'knows', 'shows', 'enclose'],
#  ['comment', 'moment'],
#  ['adieu',
#   'view',
#   'review',
#   'hue',
#   'you',
#   'grew',
#   'new',
#   'anew',
#   'due',
#   'true',
#   'untrue'],
#  ['hours', 'showers', 'flowers'],
#  ['counterfeit', 'set', 'unset', 'carcanet', 'debt'],
#  ['pain',
#   'again',
#   'contain',
#   'gain',
#   'disdain',
#   'pen',
#   'twain',
#   'remain',
#   'stain',
#   'then',
#   'amen',
#   'main',
#   'brain',
#   'men',
#   'slain'],
#  ['hearts', 'deserts', 'parts'],
#  ['graces', 'faces'],
#  ['tongue', 'belong', 'long', 'wrong', 'strong', 'young', 'song'],
#  ['declines', 'shines'],
#  ['untrimmed', 'dimmed'],
#  ['shade', 'made', 'fade', 'jade'],
#  ['paws', 'jaws'],
#  ['good', 'brood', 'blood'],
#  ["fleet'st", 'sweets'],
#  ['acquainted', 'painted', 'attainted'],
#  ['fashion', 'passion'],
#  ['rolling', 'controlling'],
#  ['gazeth', 'amazeth'],
#  ['defeated', 'created'],
#  ['a-doting', 'nothing'],
#  ['leisure', 'treasure', 'measure', 'pleasure'],
#  ['disperse', 'rehearse', 'verse', 'inhearse'],
#  ['gems', 'hems'],
#  ['wary', 'chary'],
#  ['recompense', 'eloquence'],
#  ['unrest',
#   'best',
#   'rest',
#   'guest',
#   'expressed',
#   'chest',
#   'oppressed',
#   "best'",
#   'breast',
#   'suppressed',
#   'special-blest',
#   'west',
#   'east',
#   'feast',
#   'indigest'],
#  ['sun', 'dun', 'done'],
#  ['stars', 'bars'],
#  ['most', 'boast', 'ghost', 'costs', 'lost'],
#  ['unbred',
#   'buried',
#   'bred',
#   'fled',
#   'head',
#   'remembered',
#   'tendered',
#   'astonished',
#   'red',
#   'dead',
#   "o'er-read",
#   'bed',
#   'spread'],
#  ['foiled', 'toiled'],
#  ['beloved', 'removed'],
#  ['embassage', 'vassalage'],
#  ['loving', 'moving', 'reproving'],
#  ['respect', 'effect', 'defect', 'suspect', 'aspect'],
#  ['expired', 'tired'],
#  ['slide', 'belied', 'abide', 'wide'],
#  ['reign', 'maintain', 'complain'],
#  ['heaven', 'even'],
#  ['longer', 'stronger'],
#  ['hope', 'scope'],
#  ['least', 'possessed'],
#  ['arising', 'despising'],
#  ['things', 'brings', 'kings'],
#  ['sought', 'brought', 'nought', 'thought', 'wrought'],
#  ['haste', 'last', 'past', 'taste', 'waste'],
#  ['cover', 'lover'],
#  ['green', 'seen', 'queen', 'been'],
#  ['side',
#   'eyed',
#   'bide',
#   'pride',
#   'ride',
#   'beside',
#   'aside',
#   'tied',
#   'denied',
#   'hide'],
#  ['disdaineth', 'staineth'],
#  ['cloak', 'smoke'],
#  ['speak', 'break'],
#  ['relief', 'grief', 'thief', 'chief'],
#  ['cross', 'dross', 'after-loss', 'loss'],
#  ['proceeds', 'sheds', 'breeds', 'weeds', 'exceeds', 'deeds'],
#  ['mud', 'bud'],
#  ['amis', 'is', 'this', 'his', 'amiss', 'kiss'],
#  ['dispense', 'sense', 'commence'],
#  ['resort', 'sort', 'short', 'sport', 'report'],
#  ['youth', 'truth'],
#  ['despised', 'sufficed'],
#  ['forth', 'worth'],
#  ['all', 'fall', 'call'],
#  ['receivest', 'deceivest'],
#  ['usest', 'refusest'],
#  ['liberty', 'poverty', 'injury'],
#  ['prevailed', 'assailed'],
#  ['dearly', 'nearly'],
#  ['her'],
#  ['unrespected', 'directed'],
#  ['hand', 'land', 'stand', 'brand'],
#  ['assured', 'recured', 'endured', 'cured'],
#  ['sad', 'glad'],
#  ['bar', 'war'],
#  ['determined', 'impanelled'],
#  ['look', "o'erlook", 'took', 'book'],
#  ['other', 'smother'],
#  ['trust', 'unjust', 'thrust', 'lust'],
#  ['defects', 'respects'],
#  ['here', 'uprear'],
#  ['cause', 'laws'],
#  ['need', 'exceed', 'speed'],
#  ['pace', 'race'],
#  ['redeem', 'esteem', 'deem', 'seem'],
#  ['dye', 'wantonly'],
#  ['discloses', 'roses'],
#  ['contents', 'monuments'],
#  ['overturn', 'burn'],
#  ['allayed', 'said'],
#  ['fulness', 'dulness'],
#  ['hour', 'sour'],
#  ['crave', 'slave'],
#  ['beck', 'check'],
#  ['beguiled', 'child'],
#  ['crowned', 'confound'],
#  ['broken', 'open'],
#  ['pry', 'jealousy'],
#  ['great', 'defeat'],
#  ['surmount', 'account'],
#  ['indeed', 'read'],
#  ['antiquity', 'iniquity'],
#  ['morn', "o'erworn"],
#  ['down-rased', 'defaced'],
#  ['lose', 'choose'],
#  ['sea', 'plea'],
#  ['bower', 'power', 'flower'],
#  ['stout', 'doubt', 'about', 'out'],
#  ['alack', 'back'],
#  ['hid', 'forbid'],
#  ['cry', 'jollity'],
#  ['scorn', 'forsworn', 'torn', 'born', 'outworn'],
#  ['misplaced', 'disgraced'],
#  ['disabled', 'strumpeted'],
#  ['simplicity', 'authority'],
#  ['society', 'impiety'],
#  ['seek', 'cheek'],
#  ['gains', 'veins'],
#  ['had', 'mad', 'bad'],
#  ['own', 'shown'],
#  ['charged', 'enlarged'],
#  ['blot', 'not', 'got', 'forgot', 'plot'],
#  ['sang', 'hang'],
#  ['arrest', 'interest'],
#  ['remains', 'contains'],
#  ['found', 'ground', 'sound'],
#  ['change', 'strange'],
#  ['weed', 'proceed'],
#  ['compile', 'style'],
#  ['ignorance', 'advance'],
#  ['decayed', 'aid'],
#  ['word', 'afford'],
#  ['afloat', 'boat'],
#  ['rotten', 'forgotten'],
#  ['grave', 'have'],
#  ['devised', 'sympathized'],
#  ['used', 'abused'],
#  ['mute', 'fruit', 'impute'],
#  ['glory', 'story'],
#  ['curse', 'worse'],
#  ['filed', 'compiled'],
#  ['affords', 'words'],
#  ['possessing', 'releasing'],
#  ['determinate', 'estimate'],
#  ['granting', 'wanting'],
#  ['swerving', 'deserving'],
#  ['growing', 'knowing'],
#  ['mistaking', 'making'],
#  ['flatter', 'matter'],
#  ['too', 'do'],
#  ['fault', 'halt'],
#  ['sorrow', 'morrow'],
#  ['horse', 'force'],
#  ['belongs', 'wrongs'],
#  ['difference', 'excellence', 'expense'],
#  ['privilege', 'edge'],
#  ['less', 'wantonness'],
#  ['deemed', 'esteemed'],
#  ['trim', 'him'],
#  ['amends', 'depends'],
#  ['dignified', 'dyed'],
#  ['fixed', "intermixed'"],
#  ['esteeming', 'seeming'],
#  ['burned', 'turned'],
#  ['perceived', 'deceived'],
#  ['wights', 'knights'],
#  ['control', 'soul'],
#  ['subscribes', 'tribes'],
#  ['register', 'character'],
#  ['merit', 'spirit'],
#  ['exchanged', 'ranged'],
#  ['reigned', 'stained'],
#  ['chide', 'provide'],
#  ['subdued', 'renewed'],
#  ['think', 'drink'],
#  ['correction', 'infection'],
#  ['strive', 'alive'],
#  ['dispatch', 'catch', 'latch'],
#  ['feature', 'creature'],
#  ['resemble', 'assemble'],
#  ['seeing', 'being', "'greeing"],
#  ['up', 'cup'],
#  ['begin', 'sin'],
#  ['clearer', 'dearer'],
#  ['accidents', 'intents'],
#  ['tyranny', 'incertainty'],
#  ['finds', 'minds', 'winds'],
#  ['mark', 'bark'],
#  ['taken', 'shaken', 'forsaken'],
#  ['weeks', 'reeks', 'cheeks'],
#  ['loved', 'proved'],
#  ['down', 'frown'],
#  ['keen', 'unseen'],
#  ['urge', 'purge'],
#  ['sweetness', 'meetness'],
#  ['needing', 'feeding'],
#  ['fears', 'clears', 'tears'],
#  ['win', 'within'],
#  ['committed', 'fitted'],
#  ['fever', 'never'],
#  ['greater', 'better'],
#  ['feel', 'steel'],
#  ['fits', 'hits'],
#  ['bevel', 'level'],
#  ['subsist', 'missed'],
#  ['unfathered', 'gathered'],
#  ['accident', 'discontent', 'bent'],
#  ['falls', 'calls'],
#  ['heretic', 'politic'],
#  ['ruining', 'honouring'],
#  ['favour', 'savour'],
#  ['black', 'lack'],
#  ["play'st", "sway'st"],
#  ['reap', 'leap'],
#  ['chips', 'lips'],
#  ['bait', 'straight'],
#  ['dream', 'extreme'],
#  ['crossed', 'engrossed'],
#  ['guard', 'ward'],
#  ['bail', 'gaol'],
#  ['over-plus', 'thus'],
#  ['spacious', 'gracious'],
#  ['looks', 'hooks'],
#  ['transferred', 'erred'],
#  ['injuries', 'enemies'],
#  ['express', 'press'],
#  ['denote', 'dote', 'note'],
#  ['delighted', 'invited'],
#  ['man', 'can'],
#  ['ornaments', 'rents'],
#  ['evil', 'devil'],
#  ["you'", 'threw'],
#  ['earth', 'dearth'],
#  ['please', 'disease'],
#  ['kept', 'except'],
#  ['reason', 'treason'],
#  ['bearing', 'swearing'],
#  ['blindness', 'kindness'],
#  ['endure', 'cure'],
#  ['desired', 'new-fired'],
#  ['warmed', 'disarmed'],
#  ['perpetual', 'thrall']]

# %% [markdown]
# # no don't learn rhyme!

# %%
rhyme_data_raw
# Out:
# [['cease', 'increase', 'lease', 'decease', 'decrease', 'excess'],
#  ['i',
#   'fee',
#   'die',
#   'memory',
#   'eye',
#   'legacy',
#   'deny',
#   'qualify',
#   'thee',
#   'fly',
#   'by',
#   'majesty',
#   'usury',
#   'husbandry',
#   'dignity',
#   'sky',
#   'eternity',
#   'me',
#   'canopy',
#   'be',
#   'ye',
#   'see',
#   'gravity',
#   'thereby',
#   'lie',
#   'flattery',
#   'defy',
#   'melancholy',
#   'alchemy',
#   'history',
#   'enmity',
#   'constancy',
#   'why',
#   'posterity',
#   'decree',
#   'free',
#   'fortify',
#   'remedy',
#   'idolatry',
#   'masonry'],
#  ['devise',
#   'prophecies',
#   'cries',
#   'spies',
#   'despise',
#   'eyes',
#   'subtleties',
#   'lies',
#   'arise'],
#  ['cruel', 'fuel', 'jewel'],
#  ['content',
#   'excellent',
#   'spent',
#   'invent',
#   'argument',
#   'rent',
#   'ornament',
#   'monument'],
#  ['bring',
#   'ordering',
#   'thing',
#   'niggarding',
#   'spring',
#   'prefiguring',
#   'wing',
#   'king',
#   'sing'],
#  ['allow', 'bow', 'mow', 'brow', 'now', 'bough', 'how'],
#  ['stelled', 'held', 'field'],
#  ['days', 'decays', 'praise', 'lays'],
#  ['muse', "excuse'", 'use', 'abuse'],
#  ['define', 'line', 'shine', 'thine', 'divine', 'mine'],
#  ['hold', 'bold', 'told', 'old', 'behold', 'uphold', 'cold', 'untold'],
#  ['renewest', 'viewest'],
#  ['mother', 'another'],
#  ['dumb', 'womb', 'room', 'sum', 'tomb', 'come', 'doom'],
#  ['time', 'rhyme', 'prime', 'crime'],
#  ['contend',
#   'end',
#   'friend',
#   'mend',
#   'fiend',
#   'spend',
#   "friend'",
#   'depend',
#   'commend',
#   'tend',
#   'lend'],
#  ['live', 'give', 'achieve'],
#  ['stone',
#   'gone',
#   'alone',
#   'groan',
#   'moan',
#   'loan',
#   'one',
#   'prone',
#   'foregone',
#   'none',
#   'anon',
#   'upon',
#   'on',
#   "none'"],
#  ['leave', 'deceive'],
#  ['same', 'frame', 'fame', 'blame', 'name', 'shame'],
#  ['bell', 'tell', 'hell', 'smell', 'well', 'sell', 'excel', 'dwell'],
#  ['year',
#   'ear',
#   'bear',
#   'there',
#   'everywhere',
#   'elsewhere',
#   'tear',
#   'fear',
#   'forbear',
#   'dear',
#   'cheer',
#   'swear',
#   'clear',
#   'were',
#   'where',
#   'near',
#   'appear',
#   'wear'],
#  ['bereft', 'left'],
#  ['pass', 'glass', 'was'],
#  ['sweet', 'meet', 'greet'],
#  ['chase', 'case', 'face', 'disgrace', 'deface', 'grace', 'place'],
#  ['distilled', 'self-killed'],
#  ['depart', 'convert', 'heart', 'art', 'desert', 'part', 'impart'],
#  ['repair', 'fair', 'despair', 'air', 'heir'],
#  ['write',
#   'light',
#   'sight',
#   'rite',
#   'delight',
#   'aright',
#   'bright',
#   'quite',
#   'fight',
#   'right',
#   'night',
#   'spite',
#   'white',
#   'plight',
#   'recite',
#   'appetite',
#   'might'],
#  ['skill',
#   'fill',
#   "'will'",
#   'quill',
#   'kill',
#   'will',
#   'ill',
#   'still',
#   'fulfil',
#   'hill'],
#  ['rage', 'page', 'pilgrimage', 'equipage', 'stage', 'age', 'presage'],
#  ['rare', 'prepare', 'care', 'car', 'are', 'compare'],
#  ['repay',
#   'gay',
#   're-survey',
#   'clay',
#   'stay',
#   'decay',
#   'survey',
#   'key',
#   'they',
#   'away',
#   'sway',
#   'pay',
#   'say',
#   'betray',
#   'way',
#   'play',
#   'may',
#   'day',
#   'lay',
#   'array'],
#  ['son', 'noon', 'won'],
#  ['sadly', 'gladly'],
#  ['joy', 'annoy'],
#  ['confounds', 'sounds'],
#  ['wife', 'strife', 'knife', 'life'],
#  ['weep', 'keep', 'steep', 'asleep'],
#  ['confined',
#   'find',
#   'grind',
#   'mind',
#   'blind',
#   'bind',
#   'wind',
#   'kind',
#   'behind'],
#  ['wit', 'knit', 'it', 'sit', 'writ'],
#  ['befits', 'sits', 'commits'],
#  ['many', 'any'],
#  ['evident', 'unprovident'],
#  ['hate',
#   'ruminate',
#   "hate'",
#   'ruinate',
#   'anticipate',
#   'accumulate',
#   'gait',
#   'translate',
#   'fate',
#   'debate',
#   'gate',
#   'state',
#   'advocate'],
#  ['desire', 'require', 'fire', 'expire', 'conspire', 'admire'],
#  ['remove', 'above', 'approve', 'love', "love'", 'move', 'prove'],
#  ["ow'st", "bestow'st", "grow'st"],
#  ['convertest', 'departest'],
#  ['more', 'yore', 'score', 'shore', 'before', "o'er", 'abhor', 'store'],
#  ['cherish', 'perish'],
#  ['leaves', 'sheaves'],
#  ['beard', 'herd'],
#  ['forsake', 'take', 'awake', 'sake', 'partake', 'make'],
#  ['know',
#   'overthrow',
#   'owe',
#   'wilful-slow',
#   'so',
#   'slow',
#   'show',
#   'grow',
#   'woe',
#   'no',
#   'flow',
#   'go'],
#  ['offence', 'thence', 'intelligence', 'defence', 'hence'],
#  ['pluck', 'luck'],
#  ['quality', 'astronomy'],
#  ['derive', 'thrive'],
#  ['prognosticate', 'expiate', 'temperate', 'invocate', 'date'],
#  ['rose', 'grows', 'suppose', 'those', 'foes', 'knows', 'shows', 'enclose'],
#  ['comment', 'moment'],
#  ['adieu',
#   'view',
#   'review',
#   'hue',
#   'you',
#   'grew',
#   'new',
#   'anew',
#   'due',
#   'true',
#   'untrue'],
#  ['hours', 'showers', 'flowers'],
#  ['counterfeit', 'set', 'unset', 'carcanet', 'debt'],
#  ['pain',
#   'again',
#   'contain',
#   'gain',
#   'disdain',
#   'pen',
#   'twain',
#   'remain',
#   'stain',
#   'then',
#   'amen',
#   'main',
#   'brain',
#   'men',
#   'slain'],
#  ['hearts', 'deserts', 'parts'],
#  ['graces', 'faces'],
#  ['tongue', 'belong', 'long', 'wrong', 'strong', 'young', 'song'],
#  ['declines', 'shines'],
#  ['untrimmed', 'dimmed'],
#  ['shade', 'made', 'fade', 'jade'],
#  ['paws', 'jaws'],
#  ['good', 'brood', 'blood'],
#  ["fleet'st", 'sweets'],
#  ['acquainted', 'painted', 'attainted'],
#  ['fashion', 'passion'],
#  ['rolling', 'controlling'],
#  ['gazeth', 'amazeth'],
#  ['defeated', 'created'],
#  ['a-doting', 'nothing'],
#  ['leisure', 'treasure', 'measure', 'pleasure'],
#  ['disperse', 'rehearse', 'verse', 'inhearse'],
#  ['gems', 'hems'],
#  ['wary', 'chary'],
#  ['recompense', 'eloquence'],
#  ['unrest',
#   'best',
#   'rest',
#   'guest',
#   'expressed',
#   'chest',
#   'oppressed',
#   "best'",
#   'breast',
#   'suppressed',
#   'special-blest',
#   'west',
#   'east',
#   'feast',
#   'indigest'],
#  ['sun', 'dun', 'done'],
#  ['stars', 'bars'],
#  ['most', 'boast', 'ghost', 'costs', 'lost'],
#  ['unbred',
#   'buried',
#   'bred',
#   'fled',
#   'head',
#   'remembered',
#   'tendered',
#   'astonished',
#   'red',
#   'dead',
#   "o'er-read",
#   'bed',
#   'spread'],
#  ['foiled', 'toiled'],
#  ['beloved', 'removed'],
#  ['embassage', 'vassalage'],
#  ['loving', 'moving', 'reproving'],
#  ['respect', 'effect', 'defect', 'suspect', 'aspect'],
#  ['expired', 'tired'],
#  ['slide', 'belied', 'abide', 'wide'],
#  ['reign', 'maintain', 'complain'],
#  ['heaven', 'even'],
#  ['longer', 'stronger'],
#  ['hope', 'scope'],
#  ['least', 'possessed'],
#  ['arising', 'despising'],
#  ['things', 'brings', 'kings'],
#  ['sought', 'brought', 'nought', 'thought', 'wrought'],
#  ['haste', 'last', 'past', 'taste', 'waste'],
#  ['cover', 'lover'],
#  ['green', 'seen', 'queen', 'been'],
#  ['side',
#   'eyed',
#   'bide',
#   'pride',
#   'ride',
#   'beside',
#   'aside',
#   'tied',
#   'denied',
#   'hide'],
#  ['disdaineth', 'staineth'],
#  ['cloak', 'smoke'],
#  ['speak', 'break'],
#  ['relief', 'grief', 'thief', 'chief'],
#  ['cross', 'dross', 'after-loss', 'loss'],
#  ['proceeds', 'sheds', 'breeds', 'weeds', 'exceeds', 'deeds'],
#  ['mud', 'bud'],
#  ['amis', 'is', 'this', 'his', 'amiss', 'kiss'],
#  ['dispense', 'sense', 'commence'],
#  ['resort', 'sort', 'short', 'sport', 'report'],
#  ['youth', 'truth'],
#  ['despised', 'sufficed'],
#  ['forth', 'worth'],
#  ['all', 'fall', 'call'],
#  ['receivest', 'deceivest'],
#  ['usest', 'refusest'],
#  ['liberty', 'poverty', 'injury'],
#  ['prevailed', 'assailed'],
#  ['dearly', 'nearly'],
#  ['her'],
#  ['unrespected', 'directed'],
#  ['hand', 'land', 'stand', 'brand'],
#  ['assured', 'recured', 'endured', 'cured'],
#  ['sad', 'glad'],
#  ['bar', 'war'],
#  ['determined', 'impanelled'],
#  ['look', "o'erlook", 'took', 'book'],
#  ['other', 'smother'],
#  ['trust', 'unjust', 'thrust', 'lust'],
#  ['defects', 'respects'],
#  ['here', 'uprear'],
#  ['cause', 'laws'],
#  ['need', 'exceed', 'speed'],
#  ['pace', 'race'],
#  ['redeem', 'esteem', 'deem', 'seem'],
#  ['dye', 'wantonly'],
#  ['discloses', 'roses'],
#  ['contents', 'monuments'],
#  ['overturn', 'burn'],
#  ['allayed', 'said'],
#  ['fulness', 'dulness'],
#  ['hour', 'sour'],
#  ['crave', 'slave'],
#  ['beck', 'check'],
#  ['beguiled', 'child'],
#  ['crowned', 'confound'],
#  ['broken', 'open'],
#  ['pry', 'jealousy'],
#  ['great', 'defeat'],
#  ['surmount', 'account'],
#  ['indeed', 'read'],
#  ['antiquity', 'iniquity'],
#  ['morn', "o'erworn"],
#  ['down-rased', 'defaced'],
#  ['lose', 'choose'],
#  ['sea', 'plea'],
#  ['bower', 'power', 'flower'],
#  ['stout', 'doubt', 'about', 'out'],
#  ['alack', 'back'],
#  ['hid', 'forbid'],
#  ['cry', 'jollity'],
#  ['scorn', 'forsworn', 'torn', 'born', 'outworn'],
#  ['misplaced', 'disgraced'],
#  ['disabled', 'strumpeted'],
#  ['simplicity', 'authority'],
#  ['society', 'impiety'],
#  ['seek', 'cheek'],
#  ['gains', 'veins'],
#  ['had', 'mad', 'bad'],
#  ['own', 'shown'],
#  ['charged', 'enlarged'],
#  ['blot', 'not', 'got', 'forgot', 'plot'],
#  ['sang', 'hang'],
#  ['arrest', 'interest'],
#  ['remains', 'contains'],
#  ['found', 'ground', 'sound'],
#  ['change', 'strange'],
#  ['weed', 'proceed'],
#  ['compile', 'style'],
#  ['ignorance', 'advance'],
#  ['decayed', 'aid'],
#  ['word', 'afford'],
#  ['afloat', 'boat'],
#  ['rotten', 'forgotten'],
#  ['grave', 'have'],
#  ['devised', 'sympathized'],
#  ['used', 'abused'],
#  ['mute', 'fruit', 'impute'],
#  ['glory', 'story'],
#  ['curse', 'worse'],
#  ['filed', 'compiled'],
#  ['affords', 'words'],
#  ['possessing', 'releasing'],
#  ['determinate', 'estimate'],
#  ['granting', 'wanting'],
#  ['swerving', 'deserving'],
#  ['growing', 'knowing'],
#  ['mistaking', 'making'],
#  ['flatter', 'matter'],
#  ['too', 'do'],
#  ['fault', 'halt'],
#  ['sorrow', 'morrow'],
#  ['horse', 'force'],
#  ['belongs', 'wrongs'],
#  ['difference', 'excellence', 'expense'],
#  ['privilege', 'edge'],
#  ['less', 'wantonness'],
#  ['deemed', 'esteemed'],
#  ['trim', 'him'],
#  ['amends', 'depends'],
#  ['dignified', 'dyed'],
#  ['fixed', "intermixed'"],
#  ['esteeming', 'seeming'],
#  ['burned', 'turned'],
#  ['perceived', 'deceived'],
#  ['wights', 'knights'],
#  ['control', 'soul'],
#  ['subscribes', 'tribes'],
#  ['register', 'character'],
#  ['merit', 'spirit'],
#  ['exchanged', 'ranged'],
#  ['reigned', 'stained'],
#  ['chide', 'provide'],
#  ['subdued', 'renewed'],
#  ['think', 'drink'],
#  ['correction', 'infection'],
#  ['strive', 'alive'],
#  ['dispatch', 'catch', 'latch'],
#  ['feature', 'creature'],
#  ['resemble', 'assemble'],
#  ['seeing', 'being', "'greeing"],
#  ['up', 'cup'],
#  ['begin', 'sin'],
#  ['clearer', 'dearer'],
#  ['accidents', 'intents'],
#  ['tyranny', 'incertainty'],
#  ['finds', 'minds', 'winds'],
#  ['mark', 'bark'],
#  ['taken', 'shaken', 'forsaken'],
#  ['weeks', 'reeks', 'cheeks'],
#  ['loved', 'proved'],
#  ['down', 'frown'],
#  ['keen', 'unseen'],
#  ['urge', 'purge'],
#  ['sweetness', 'meetness'],
#  ['needing', 'feeding'],
#  ['fears', 'clears', 'tears'],
#  ['win', 'within'],
#  ['committed', 'fitted'],
#  ['fever', 'never'],
#  ['greater', 'better'],
#  ['feel', 'steel'],
#  ['fits', 'hits'],
#  ['bevel', 'level'],
#  ['subsist', 'missed'],
#  ['unfathered', 'gathered'],
#  ['accident', 'discontent', 'bent'],
#  ['falls', 'calls'],
#  ['heretic', 'politic'],
#  ['ruining', 'honouring'],
#  ['favour', 'savour'],
#  ['black', 'lack'],
#  ["play'st", "sway'st"],
#  ['reap', 'leap'],
#  ['chips', 'lips'],
#  ['bait', 'straight'],
#  ['dream', 'extreme'],
#  ['crossed', 'engrossed'],
#  ['guard', 'ward'],
#  ['bail', 'gaol'],
#  ['over-plus', 'thus'],
#  ['spacious', 'gracious'],
#  ['looks', 'hooks'],
#  ['transferred', 'erred'],
#  ['injuries', 'enemies'],
#  ['express', 'press'],
#  ['denote', 'dote', 'note'],
#  ['delighted', 'invited'],
#  ['man', 'can'],
#  ['ornaments', 'rents'],
#  ['evil', 'devil'],
#  ["you'", 'threw'],
#  ['earth', 'dearth'],
#  ['please', 'disease'],
#  ['kept', 'except'],
#  ['reason', 'treason'],
#  ['bearing', 'swearing'],
#  ['blindness', 'kindness'],
#  ['endure', 'cure'],
#  ['desired', 'new-fired'],
#  ['warmed', 'disarmed'],
#  ['perpetual', 'thrall']]

# %%
# we first train an HMM on the backward sequence
reversed_data = []
for sonnet in hehe:
    for line in sonnet:
        line.reverse()
        temp = line
        reversed_data.append(temp)
# Out:
# [[5, 4, 3, 2, 1, 0],
#  [12, 11, 10, 9, 8, 7, 6],
#  [20, 19, 18, 17, 16, 15, 14, 13],
#  [25, 21, 24, 10, 23, 22, 21],
#  [32, 31, 30, 29, 28, 27, 26, 13],
#  [39, 38, 37, 36, 35, 34, 33],
#  [45, 44, 43, 42, 41, 40],
#  [50, 49, 46, 48, 34, 28, 47, 34, 46, 34],
#  [55, 54, 53, 15, 52, 51, 6, 26],
#  [60, 59, 15, 28, 58, 57, 56],
#  [64, 34, 63, 62, 30, 29, 61],
#  [69, 68, 67, 66, 65, 22, 56],
#  [76, 75, 74, 73, 72, 71, 15, 70],
#  [80, 56, 79, 15, 18, 78, 53, 15, 77, 28],
#  [86, 34, 85, 84, 83, 82, 81],
#  [90, 8, 34, 68, 89, 88, 87, 56],
#  [52, 96, 95, 94, 93, 92, 91, 34],
#  [103, 102, 101, 100, 99, 98, 41, 76, 97],
#  [45, 108, 34, 107, 43, 106, 105, 104],
#  [111, 110, 34, 100, 109, 15, 107, 43],
#  [32, 113, 88, 30, 29, 61, 112, 28],
#  [119, 118, 56, 117, 116, 115, 114],
#  [124, 8, 34, 123, 119, 122, 121, 120],
#  [131, 100, 130, 129, 128, 127, 126, 26, 125],
#  [137, 136, 133, 135, 56, 134, 133, 132, 84],
#  [29, 139, 18, 108, 21, 138],
#  [136, 51, 26, 81, 141, 140, 76, 28, 114, 74],
#  [1150, 703, 163, 1998, 517, 580, 381],
#  [1566, 30, 131, 321, 498, 165, 122, 325, 28],
#  ...]

# %%
rdata = copy.deepcopy(reversed_data)

# %%
HMM_reversed_20 = unsupervised_HMM(rdata, 20, 10)
# Out:
# 3202
# Iteration: 10

# %%
def get_rhyming_words(word, rhyme_data):
    for pot_list in rhyme_data:
        if word in pot_list:
            return pot_list
    return []

def choose_ending_words(rhyme_data):
    temp = copy.deepcopy(rhyme_data)
    # choosing rhyming scheme per uniform distribution
    choices = [np.random.randint(0, len(rhyme_data)) for _ in range(7)]
    words = []
    for i in range(len(choices)):
        choice1 = random.choice(temp[choices[i]])
        words.append(choice1)
        temp[choices[i]].remove(choice1)
        choice2 = random.choice(temp[choices[i]])
        words.append(choice2)
        temp[choices[i]].remove(choice2)
    
    
    return words

# %%
# take first thing that is int thing in txt
meter_data = {}
with open("../data/Syllable_dictionary.txt", "r") as f:
    for line in f:
        temp = line.strip().split(" ")
        word = temp[0]
        count = temp[1:]
        
        for possible_val in count:
            if possible_val.isdigit():
                meter_data[word] = int(possible_val)
                break

# %%
# in the form aabb ccdd eeff gg
end_words = choose_ending_words(rhyme_data_raw)

# %%
# start at the state most likely to have that end_word
start_word = end_words[1]
temp = np.array(HMM_reversed_20.O)
most_probable_start_state = np.argmax(temp[:, dic_to_ids[start_word]])
# Out:
# 12

# %%
def generate_emission_sequential(syl_count, A, O, start_word):
    temp = np.array(O)
    most_probable_start_state = np.argmax(temp[:, dic_to_ids[start_word]])
    
    emission = []
    states = []

    # choose starting state
    y_i = most_probable_start_state
    states.append(y_i)

    counter = meter_data[start_word]
    emission.append(dic_to_ids[start_word])
    while counter < syl_count:
        y_i = int(y_i)
        # print(len(self.O[y_i]))
        array = range(len(O[y_i]))
        observation_index = np.random.choice(array, p=O[y_i])
        while counter + meter_data[ids_to_dic[observation_index]] > syl_count:
#             print("uhoh")
            observation_index = np.random.choice(array, p=O[y_i])
            
        emission.append(observation_index)
        counter += meter_data[ids_to_dic[observation_index]]
        
    return emission, states

# %%
emission, states = generate_emission_sequential(10, HMM_reversed_20.A, HMM_reversed_20.O, end_words[0])

# %%
poem = []
for i in range(14):
    start_state = end_words[i]
    emission, states = generate_emission_sequential(10, HMM_reversed_20.A, HMM_reversed_20.O, start_state)
    emission.reverse()
    x = ' '.join([str(ids_to_dic[i]) for i in emission])
    poem.append(x)

# %%
# switch order
temp = poem[1]
poem[1] = poem[2]
poem[2] = temp

temp = poem[5]
poem[5] = poem[6]
poem[6] = temp

temp = poem[9]
poem[9] = poem[10]
poem[10] = temp

for line in poem:
    print(line)
# Out:
# shaken accidents rehearse bar admire
# alone after-loss kill reap trim require
# die of him now of peace that my praised bail
# indeed estimate recite sit same gaol
# sit denied so pay how gone knowing drink
# beauteous when selling thing remembered forth
# at knife robs abused o from by for think
# so murd'rous be marvel unlettered worth
# deem over-plus suppose night dye begin
# thine in alone boast wide despised sin
# hour divine fee muse bold crowned possessing
# scorn rents reign accidents need releasing
# awake delight new tied which bow you fits
# slide effect cherish memory free hits
